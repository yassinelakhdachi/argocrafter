# %%
pip install pandas numpy matplotlib seaborn scikit-learn streamlit
# Out:
# Requirement already satisfied: pandas in c:\users\yqssine\downloads\lib\site-packages (1.4.3)
# Requirement already satisfied: numpy in c:\users\yqssine\downloads\lib\site-packages (1.23.0)
# Requirement already satisfied: matplotlib in c:\users\yqssine\downloads\lib\site-packages (3.5.2)
# Requirement already satisfied: seaborn in c:\users\yqssine\downloads\lib\site-packages (0.11.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.2-cp38-cp38-win_amd64.whl (8.3 MB)
#      ---------------------------------------- 8.3/8.3 MB 4.6 MB/s eta 0:00:00
# Collecting streamlit
#   Downloading streamlit-1.22.0-py2.py3-none-any.whl (8.9 MB)
#      ---------------------------------------- 8.9/8.9 MB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\yqssine\downloads\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\yqssine\downloads\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yqssine\downloads\lib\site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\yqssine\downloads\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\yqssine\downloads\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yqssine\downloads\lib\site-packages (from matplotlib) (1.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\yqssine\downloads\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\yqssine\downloads\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\yqssine\downloads\lib\site-packages (from seaborn) (1.8.1)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      -------------------------------------- 164.8/164.8 kB 5.0 MB/s eta 0:00:00
# Collecting importlib-metadata>=1.4
#   Using cached importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Collecting rich>=10.11.0
#   Downloading rich-13.3.5-py3-none-any.whl (238 kB)
#      -------------------------------------- 238.7/238.7 kB 4.9 MB/s eta 0:00:00
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting blinker>=1.0.0
#   Using cached blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting cachetools>=4.0
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting tenacity<9,>=8.0.0
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tornado>=6.0.3 in c:\users\yqssine\downloads\lib\site-packages (from streamlit) (6.2)
# Collecting click>=7.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting typing-extensions>=3.10.0.0
#   Using cached typing_extensions-4.6.2-py3-none-any.whl (31 kB)
# Collecting tzlocal>=1.1
#   Using cached tzlocal-5.0.1-py3-none-any.whl (20 kB)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-12.0.0-cp38-cp38-win_amd64.whl (21.5 MB)
#      ---------------------------------------- 21.5/21.5 MB 3.8 MB/s eta 0:00:00
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ---------------------------------------- 4.8/4.8 MB 4.1 MB/s eta 0:00:00
# Collecting protobuf<4,>=3.12
#   Downloading protobuf-3.20.3-cp38-cp38-win_amd64.whl (904 kB)
#      -------------------------------------- 904.4/904.4 kB 4.1 MB/s eta 0:00:00
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      -------------------------------------- 184.3/184.3 kB 3.8 MB/s eta 0:00:00
# Collecting requests>=2.4
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting watchdog
#   Downloading watchdog-3.0.0-py3-none-win_amd64.whl (82 kB)
#      ---------------------------------------- 82.0/82.0 kB 1.5 MB/s eta 0:00:00
# Collecting altair<5,>=3.2.0
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      -------------------------------------- 813.6/813.6 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in c:\users\yqssine\downloads\lib\site-packages (from altair<5,>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\yqssine\downloads\lib\site-packages (from altair<5,>=3.2.0->streamlit) (4.6.2)
# Collecting toolz
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Requirement already satisfied: jinja2 in c:\users\yqssine\downloads\lib\site-packages (from altair<5,>=3.2.0->streamlit) (3.1.2)
# Requirement already satisfied: colorama in c:\users\yqssine\downloads\lib\site-packages (from click>=7.0->streamlit) (0.4.5)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\yqssine\downloads\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\yqssine\downloads\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.0.2-py3-none-any.whl (123 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp38-cp38-win_amd64.whl (96 kB)
#      ---------------------------------------- 96.4/96.4 kB 2.7 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ---------------------------------------- 84.5/84.5 kB 2.4 MB/s eta 0:00:00
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading Pygments-2.15.1-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 3.8 MB/s eta 0:00:00
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-win_amd64.whl (38 kB)
# Collecting tzdata
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\yqssine\downloads\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yqssine\downloads\lib\site-packages (from jinja2->altair<5,>=3.2.0->streamlit) (2.1.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\yqssine\downloads\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (5.8.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\yqssine\downloads\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\yqssine\downloads\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (0.18.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using legacy 'setup.py install' for validators, since package 'wheel' is not installed.
# Installing collected packages: watchdog, validators, urllib3, tzdata, typing-extensions, toolz, toml, threadpoolctl, tenacity, smmap, pympler, pygments, pyarrow, protobuf, mdurl, joblib, importlib-metadata, idna, click, charset-normalizer, certifi, cachetools, blinker, backports.zoneinfo, tzlocal, scikit-learn, requests, pydeck, markdown-it-py, gitdb, rich, gitpython, altair, streamlit
#   Running setup.py install for validators: started
#   Running setup.py install for validators: finished with status 'done'
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.12.0
#     Uninstalling Pygments-2.12.0:
#       Successfully uninstalled Pygments-2.12.0
# Successfully installed altair-4.2.2 backports.zoneinfo-0.2.1 blinker-1.6.2 cachetools-5.3.1 certifi-2023.5.7 charset-normalizer-3.1.0 click-8.1.3 gitdb-4.0.10 gitpython-3.1.31 idna-3.4 importlib-metadata-6.6.0 joblib-1.2.0 markdown-it-py-2.2.0 mdurl-0.1.2 protobuf-3.20.3 pyarrow-12.0.0 pydeck-0.8.1b0 pygments-2.15.1 pympler-1.0.1 requests-2.31.0 rich-13.3.5 scikit-learn-1.2.2 smmap-5.0.0 streamlit-1.22.0 tenacity-8.2.2 threadpoolctl-3.1.0 toml-0.10.2 toolz-0.12.0 typing-extensions-4.6.2 tzdata-2023.3 tzlocal-5.0.1 urllib3-2.0.2 validators-0.20.0 watchdog-3.0.0
#
# [notice] A new release of pip available: 22.1.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Yqssine\OneDrive\Documents\IT_Career\PFA\ML\diascan\diascan\main.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Yqssine/OneDrive/Documents/IT_Career/PFA/ML/diascan/diascan/main.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from google.colab import files
#       <a href='vscode-notebook-cell:/c%3A/Users/Yqssine/OneDrive/Documents/IT_Career/PFA/ML/diascan/diascan/main.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
df = pd.read_csv('diabetes.csv')

# %%
# Check for missing values
print(df.isnull().sum())

# Check for outliers
import seaborn as sns
sns.boxplot(data=df)
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# <AxesSubplot:>

# %%
# Handling missing values
df['Glucose'].fillna(df['Glucose'].mean(), inplace=True)

# Handling outliers
q1 = df['BMI'].quantile(0.25)
q3 = df['BMI'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
df = df[(df['BMI'] >= lower_bound) & (df['BMI'] <= upper_bound)]

# Transforming data
df['Age'] = df['Age'].apply(lambda x: 1 if x > 30 else 0)

# %%
#Performing EDA
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of the target variable
sns.countplot(df['Outcome'])
plt.title('Distribution of the Target Variable')
plt.show()

# Correlation matrix
sns.heatmap(df.corr(), annot=True)
plt.title('Correlation Matrix')
plt.show()

# Distribution of features by target variable
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']

for feature in features:
    sns.boxplot(x='Outcome', y=feature, data=df)
    plt.title(f'{feature} by Target Variable')
    plt.show()
# Out:
# c:\Users\Yqssine\Downloads\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Feature scaling
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# Feature selection
X = df.drop('Outcome', axis=1)
y = df['Outcome']

from sklearn.feature_selection import SelectKBest, f_classif

selector = SelectKBest(f_classif, k=5)
X_new = selector.fit_transform(X, y)
selected_features = X.columns[selector.get_support(indices=True)]

# %%
# Splitting the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

# Building the model
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Evaluating the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.8133333333333334
# Precision: 0.7368421052631579
# Recall: 0.6086956521739131
# F1 Score: 0.6666666666666666
